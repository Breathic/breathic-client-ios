# %%
import os
import numpy as np
import seaborn as sns
import pandas as pd
import subprocess
from dtw import correlate
import json
import librosa
import IPython.display as ipd
from random import random
import math

MAX_AUDIO_DURATION = 0.5
MAX_SAMPLE_COUNT_PER_ARTIST = 100
MAX_SAMPLE_COMPARISON_COUNT = 50

apppath = os.path.expanduser('/Users/andrusasumets/projects/experiments/pacemaker/')
processedpath = os.path.join(apppath, 'processed/')
soxipath = os.path.join(processedpath, 'soxi/')
wavpath = os.path.join(processedpath, 'wav/')
audiopath = os.path.join(processedpath, 'audio/')
normalizedpath = os.path.join(processedpath, 'normalized/')
dtwpath = os.path.join(processedpath, 'dtw/')
extensionpath = os.path.join(apppath, 'pacemaker WatchKit Extension/data/')
extensionsamplepath = os.path.join(extensionpath, 'samples/')
librarypath = os.path.expanduser('/Volumes/LaCie/freesound-crawler/downloads/')
allowedfileformats = ['wav', 'aiff', 'flac', 'ogg', 'mp3', 'm4a']
audiofileformat = 'm4a'

for p in [processedpath, soxipath, wavpath, audiopath, normalizedpath, dtwpath, extensionpath, extensionsamplepath]:
    if not os.path.exists(p):
        os.makedirs(p)

# %%
'''
f = open(apppath + 'artists.txt')
artists = ''.join(f.readlines()).strip().replace('\n', ',').split(',')
print('artists:', len(artists))
print(artists)
'''
# Out:
# "\nf = open(apppath + 'artists.txt')\nartists = ''.join(f.readlines()).strip().replace('\n', ',').split(',')\nprint('artists:', len(artists))\nprint(artists)\n"

# %%
def get_fileformat(filename):
    return filename.split('.')[len(filename.split('.')) - 1]

all_filenames = [f for f in os.listdir(librarypath)]
fileformats = {}
for filename in all_filenames:
    fileformat = get_fileformat(filename)
    
    if fileformat not in fileformats:
        fileformats[fileformat] = 0
         
    fileformats[fileformat] = fileformats[fileformat] + 1
    
print('fileformats', fileformats)
print('all_filenames:', len(all_filenames))

filenames = [f for f in os.listdir(librarypath) if f.endswith(tuple(allowedfileformats))]
filenames = [f for f in filenames if f.count('__') == 2]
processedfilenames = [f for f in os.listdir(audiopath) if f.endswith(audiofileformat)]
# Out:
# fileformats {'wav': 43017, 'mp3': 2756, 'aiff': 17770, 'flac': 2696, 'ogg': 588, 'm4a': 141, 'crdownload': 7, 'DS_Store': 1}
# all_filenames: 66976

# %%
def create_or_read_file(command, outfilename):
    if os.path.exists(outfilename):
        f = open(outfilename, "r")
        out = ''.join(f.readlines())
        f.close()
        return out
    else:
        try:
            out = str(subprocess.check_output(command).decode(encoding="utf-8")).strip().replace('\\n', '').replace("'", "")

            with open(outfilename, 'w') as file:
                file.write(out)

            return out
        except Exception as e:
            return

# %%
def process(command):
    subprocess.check_output(command)

sample_artists = {}
sample_durations = {}
res = []

for filename in filenames:
    try:
        fileartist = filename.split("__")[1].split("__")[0]
        fileid = filename.split('__')[0]
        audiofilename = fileid + '.' + audiofileformat

        #if fileartist not in artists:
            #continue

        if fileartist not in sample_artists:
            sample_artists[fileartist] = 0

        sample_artists[fileartist] = sample_artists[fileartist] + 1

        if sample_artists[fileartist] >= MAX_SAMPLE_COUNT_PER_ARTIST:
            continue

        soxi_out = create_or_read_file(['soxi', '-D', librarypath + filename], soxipath + fileid + '.soxi')
        if not soxi_out:
            continue

        sample_duration = float(soxi_out)
        if sample_duration > MAX_AUDIO_DURATION:
            continue

        if audiofilename not in processedfilenames:
            process(['ffmpeg-normalize', librarypath + filename, '-o', normalizedpath + filename])
            process(['ffmpeg', '-loglevel', 'error', '-i', normalizedpath + filename, '-acodec', 'pcm_s16le', '-ac', '1', '-ar', '100', '-threads', '6', '-y', wavpath + fileid + '.wav'])
            process(['ffmpeg', '-loglevel', 'error', '-i', normalizedpath + filename, '-c:a', 'aac', '-ar', '44100', '-threads', '6', '-y', audiopath + audiofilename])
        
        sample_durations[fileid] = sample_duration
        res.append(audiofilename)
    except Exception as e:
        print(e)

filenames = res
print(filenames)
print(len(filenames))
print(sample_artists)
# Out:
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/634258__darcyadam__28-overtone-flutter.aiff -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-0.0:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s24le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/iv4if6ko.aiff! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/634258__darcyadam__28-overtone-flutter.aiff', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-0.0:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s24le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/iv4if6ko.aiff']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, aiff, from '/Volumes/LaCie/freesound-crawler/downloads/634258__darcyadam__28-overtone-flutter.aiff':
# Duration: 00:00:00.22, start: 0.000000, bitrate: 1153 kb/s
# Stream #0:0: Audio: pcm_s24be, 48000 Hz, mono, s32 (24 bit), 1152 kb/s
# Stream mapping:
# Stream #0:0 (pcm_s24be) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s24le)
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fe925204080]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/634258__darcyadam__28-overtone-flutter.aiff', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-0.0:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s24le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/iv4if6ko.aiff']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, aiff, from '/Volumes/LaCie/freesound-crawler/downloads/634258__darcyadam__28-overtone-flutter.aiff':
# Duration: 00:00:00.22, start: 0.000000, bitrate: 1153 kb/s
# Stream #0:0: Audio: pcm_s24be, 48000 Hz, mono, s32 (24 bit), 1152 kb/s
# Stream mapping:
# Stream #0:0 (pcm_s24be) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s24le)
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fe925204080]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/634258__darcyadam__28-overtone-flutter.aiff', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/634258__darcyadam__28-overtone-flutter.aiff']' returned non-zero exit status 1.
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/139582__gherat__button-master-006.aiff -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-21.0:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s24le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/e9sy35w0.aiff! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/139582__gherat__button-master-006.aiff', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-21.0:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s24le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/e9sy35w0.aiff']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, aiff, from '/Volumes/LaCie/freesound-crawler/downloads/139582__gherat__button-master-006.aiff':
# Duration: 00:00:00.02, start: 0.000000, bitrate: 2143 kb/s
# Stream #0:0: Audio: pcm_s24be, 44100 Hz, stereo, s32 (24 bit), 2116 kb/s
# Stream mapping:
# Stream #0:0 (pcm_s24be) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s24le)
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7f904c104080]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/139582__gherat__button-master-006.aiff', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-21.0:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s24le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/e9sy35w0.aiff']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, aiff, from '/Volumes/LaCie/freesound-crawler/downloads/139582__gherat__button-master-006.aiff':
# Duration: 00:00:00.02, start: 0.000000, bitrate: 2143 kb/s
# Stream #0:0: Audio: pcm_s24be, 44100 Hz, stereo, s32 (24 bit), 2116 kb/s
# Stream mapping:
# Stream #0:0 (pcm_s24be) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s24le)
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7f904c104080]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# soxi FAIL formats: no handler for file extension `m4a'
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/139582__gherat__button-master-006.aiff', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/139582__gherat__button-master-006.aiff']' returned non-zero exit status 1.
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/459223__soneproject__snare0dc5.flac -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-11.5:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s32le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/n8oytsza.flac! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/459223__soneproject__snare0dc5.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-11.5:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/n8oytsza.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/459223__soneproject__snare0dc5.flac':
# Metadata:
# Comment         : Processed by SoX
# Duration: 00:00:00.27, start: 0.000000, bitrate: 1455 kb/s
# Stream #0:0: Audio: flac, 48000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7f8a9c707d00] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7f8a9c711380]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/459223__soneproject__snare0dc5.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-11.5:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/n8oytsza.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/459223__soneproject__snare0dc5.flac':
# Metadata:
# Comment         : Processed by SoX
# Duration: 00:00:00.27, start: 0.000000, bitrate: 1455 kb/s
# Stream #0:0: Audio: flac, 48000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7f8a9c707d00] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7f8a9c711380]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/459223__soneproject__snare0dc5.flac', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/459223__soneproject__snare0dc5.flac']' returned non-zero exit status 1.
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/183332__unfa__beatbox-shaker-take-5.flac -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-38.31:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s32le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/qdbsh58x.flac! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/183332__unfa__beatbox-shaker-take-5.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-38.31:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/qdbsh58x.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/183332__unfa__beatbox-shaker-take-5.flac':
# Duration: 00:00:00.28, start: 0.000000, bitrate: 2010 kb/s
# Stream #0:0: Audio: flac, 96000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fdbae906c40] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fdbaed04e00]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/183332__unfa__beatbox-shaker-take-5.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-38.31:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/qdbsh58x.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/183332__unfa__beatbox-shaker-take-5.flac':
# Duration: 00:00:00.28, start: 0.000000, bitrate: 2010 kb/s
# Stream #0:0: Audio: flac, 96000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fdbae906c40] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fdbaed04e00]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/183332__unfa__beatbox-shaker-take-5.flac', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/183332__unfa__beatbox-shaker-take-5.flac']' returned non-zero exit status 1.
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/183358__unfa__beatbox-hihat-take-32.flac -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-37.2:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s32le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/m_8dt_vd.flac! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/183358__unfa__beatbox-hihat-take-32.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-37.2:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/m_8dt_vd.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/183358__unfa__beatbox-hihat-take-32.flac':
# Duration: 00:00:00.24, start: 0.000000, bitrate: 1968 kb/s
# Stream #0:0: Audio: flac, 96000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7faa2ff08000] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7faa30905340]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/183358__unfa__beatbox-hihat-take-32.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-37.2:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/m_8dt_vd.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/183358__unfa__beatbox-hihat-take-32.flac':
# Duration: 00:00:00.24, start: 0.000000, bitrate: 1968 kb/s
# Stream #0:0: Audio: flac, 96000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7faa2ff08000] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7faa30905340]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/183358__unfa__beatbox-hihat-take-32.flac', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/183358__unfa__beatbox-hihat-take-32.flac']' returned non-zero exit status 1.
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/457699__soneproject__noisemaker-sawc4.flac -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-0.93:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s32le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/9eygy7r4.flac! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/457699__soneproject__noisemaker-sawc4.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-0.93:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/9eygy7r4.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/457699__soneproject__noisemaker-sawc4.flac':
# Metadata:
# Comment         : Processed by SoX
# Duration: 00:00:00.01, bitrate: 955 kb/s
# Stream #0:0: Audio: flac, 44100 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fd41e806c40] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fd41ea04540]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/457699__soneproject__noisemaker-sawc4.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-0.93:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/9eygy7r4.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/457699__soneproject__noisemaker-sawc4.flac':
# Metadata:
# Comment         : Processed by SoX
# Duration: 00:00:00.01, bitrate: 955 kb/s
# Stream #0:0: Audio: flac, 44100 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fd41e806c40] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fd41ea04540]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/457699__soneproject__noisemaker-sawc4.flac', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/457699__soneproject__noisemaker-sawc4.flac']' returned non-zero exit status 1.
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/441724__soundx360__drum-pad1.mp3', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/441724__soundx360__drum-pad1.mp3']' returned non-zero exit status 1.
# ERROR: Output extension mp3 does not support PCM audio. Please choose a suitable audio codec with the -c:a option.
# ERROR: Output extension mp3 does not support PCM audio. Please choose a suitable audio codec with the -c:a option.
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/560803__miles-thompson__accordion-minor-ab.mp3', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/560803__miles-thompson__accordion-minor-ab.mp3']' returned non-zero exit status 1.
# WARNING: Audio stream has a duration of less than 3 seconds. Normalization may not work. See https://github.com/slhck/ffmpeg-normalize/issues/87 for more info.
# ERROR: Error while running command /usr/local/bin/ffmpeg -y -nostdin -i /Volumes/LaCie/freesound-crawler/downloads/183367__unfa__beatbox-hihat-take-6.flac -filter_complex '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-42.88:measured_thresh=-70.0:linear=true:print_format=json[norm0]' -map_metadata 0 -map_metadata:s:a:0 0:s:a:0 -map_chapters 0 -map '[norm0]' -c:a:0 pcm_s32le -c:s copy /var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/r0fm440v.flac! Error: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/183367__unfa__beatbox-hihat-take-6.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-42.88:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/r0fm440v.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/183367__unfa__beatbox-hihat-take-6.flac':
# Duration: 00:00:00.36, start: 0.000000, bitrate: 1986 kb/s
# Stream #0:0: Audio: flac, 96000 Hz, stereo, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fa8df907c40] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fa8df804f40]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# ...
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/534522__pbimal__stock-tongue-01.flac':
# Duration: 00:00:00.29, start: 0.000000, bitrate: 676 kb/s
# Stream #0:0: Audio: flac, 44100 Hz, mono, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fa862905880] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fa862904200]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Traceback (most recent call last):
#   File "/usr/local/bin/ffmpeg-normalize", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/__main__.py", line 554, in main
#     ffmpeg_normalize.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 205, in run_normalization
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_ffmpeg_normalize.py", line 194, in run_normalization
#     media_file.run_normalization()
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 165, in run_normalization
#     for _ in self._second_pass():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 381, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 370, in _second_pass
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_media_file.py", line 362, in _second_pass
#     for progress in cmd_runner.run_ffmpeg_command():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_normalize/_cmd_utils.py", line 78, in run_ffmpeg_command
#     for progress in ff.run_command_with_progress():
#   File "/usr/local/lib/python3.9/site-packages/ffmpeg_progress_yield/ffmpeg_progress_yield.py", line 107, in run_command_with_progress
#     raise RuntimeError(
# RuntimeError: Error running command ['/usr/local/bin/ffmpeg', '-y', '-nostdin', '-i', '/Volumes/LaCie/freesound-crawler/downloads/534522__pbimal__stock-tongue-01.flac', '-filter_complex', '[0:0]loudnorm=i=-23.0:lra=7.0:tp=-2.0:offset=0.0:measured_i=-99.0:measured_lra=0.0:measured_tp=-2.86:measured_thresh=-70.0:linear=true:print_format=json[norm0]', '-map_metadata', '0', '-map_metadata:s:a:0', '0:s:a:0', '-map_chapters', '0', '-map', '[norm0]', '-c:a:0', 'pcm_s32le', '-c:s', 'copy', '/var/folders/94/c53y6yld37z20wdsvhhlk58c0000gn/T/6_looyt1.flac']: ffmpeg version 5.1.1 Copyright (c) 2000-2022 the FFmpeg developers
# built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
# configuration: --prefix=/usr/local/Cellar/ffmpeg/5.1.1-with-options --enable-shared --cc=clang --host-cflags= --host-ldflags= --enable-gpl --enable-libaom --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-libsnappy --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-demuxer=dash --enable-opencl --enable-audiotoolbox --enable-videotoolbox --disable-htmlpages --enable-libfdk-aac --enable-nonfree
# libavutil      57. 28.100 / 57. 28.100
# libavcodec     59. 37.100 / 59. 37.100
# libavformat    59. 27.100 / 59. 27.100
# libavdevice    59.  7.100 / 59.  7.100
# libavfilter     8. 44.100 /  8. 44.100
# libswscale      6.  7.100 /  6.  7.100
# libswresample   4.  7.100 /  4.  7.100
# libpostproc    56.  6.100 / 56.  6.100
# Input #0, flac, from '/Volumes/LaCie/freesound-crawler/downloads/534522__pbimal__stock-tongue-01.flac':
# Duration: 00:00:00.29, start: 0.000000, bitrate: 676 kb/s
# Stream #0:0: Audio: flac, 44100 Hz, mono, s32 (24 bit)
# Stream mapping:
# Stream #0:0 (flac) -> loudnorm:default
# loudnorm:default -> Stream #0:0 (pcm_s32le)
# [flac @ 0x7fa862905880] Invalid audio stream. Exactly one FLAC audio stream is required.
# Could not write header for output file #0 (incorrect codec parameters ?): Invalid argument
# Error initializing output stream 0:0 --
# [Parsed_loudnorm_0 @ 0x7fa862904200]
# {
# "input_i" : "-inf",
# "input_tp" : "-inf",
# "input_lra" : "0.00",
# "input_thresh" : "-70.00",
# "output_i" : "-inf",
# "output_tp" : "-inf",
# "output_lra" : "0.00",
# "output_thresh" : "-70.00",
# "normalization_type" : "dynamic",
# "target_offset" : "inf"
# }
# Conversion failed!
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/534522__pbimal__stock-tongue-01.flac', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/534522__pbimal__stock-tongue-01.flac']' returned non-zero exit status 1.
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/545349__stwime__pan2.ogg', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/545349__stwime__pan2.ogg']' returned non-zero exit status 1.
# ERROR: Output extension ogg does not support PCM audio. Please choose a suitable audio codec with the -c:a option.
# soxi FAIL formats: no handler for file extension `m4a'
# soxi FAIL formats: no handler for file extension `m4a'
# ERROR: Output extension mp3 does not support PCM audio. Please choose a suitable audio codec with the -c:a option.
# ERROR: Output extension ogg does not support PCM audio. Please choose a suitable audio codec with the -c:a option.
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/560821__miles-thompson__accordion-minor-a.mp3', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/560821__miles-thompson__accordion-minor-a.mp3']' returned non-zero exit status 1.
# Command '['ffmpeg-normalize', '/Volumes/LaCie/freesound-crawler/downloads/545355__stwime__pan3.ogg', '-o', '/Users/andrusasumets/projects/experiments/pacemaker/processed/normalized/545355__stwime__pan3.ogg']' returned non-zero exit status 1.
# ['634246.m4a', '626685.m4a', '267818.m4a', '194063.m4a', '589597.m4a', '335813.m4a', '491458.m4a', '194138.m4a', '589230.m4a', '349729.m4a', '368869.m4a', '614382.m4a', '8735.m4a', '456471.m4a', '514352.m4a', '568294.m4a', '375658.m4a', '582707.m4a', '430091.m4a', '375817.m4a', '10090.m4a', '435305.m4a', '621916.m4a', '139601.m4a', '627258.m4a', '621703.m4a', '611852.m4a', '375833.m4a', '430085.m4a', '384147.m4a', '250445.m4a', '488202.m4a', '375879.m4a', '335842.m4a', '375881.m4a', '54011.m4a', '447245.m4a', '582664.m4a', '577162.m4a', '53628.m4a', '542848.m4a', '625049.m4a', '623945.m4a', '629396.m4a', '523997.m4a', '107283.m4a', '548514.m4a', '375639.m4a', '508574.m4a', '590338.m4a', '551372.m4a', '335828.m4a', '107868.m4a', '589277.m4a', '467784.m4a', '626479.m4a', '623487.m4a', '623641.m4a', '188383.m4a', '37404.m4a', '590396.m4a', '590404.m4a', '584786.m4a', '260336.m4a', '621701.m4a', '621717.m4a', '349721.m4a', '626708.m4a', '624205.m4a', '158935.m4a', '349725.m4a', '101065.m4a', '350382.m4a', '335832.m4a', '178757.m4a', '626692.m4a', '592466.m4a', '619428.m4a', '194090.m4a', '506765.m4a', '404743.m4a', '629656.m4a', '548526.m4a', '335812.m4a', '250458.m4a', '516124.m4a', '589231.m4a', '527392.m4a', '191252.m4a', '349735.m4a', '589225.m4a', '10019.m4a', '258872.m4a', '90809.m4a', '576392.m4a', '194054.m4a', '489857.m4a', '535684.m4a', '590596.m4a', '375674.m4a', '626623.m4a', '470848.m4a', '245733.m4a', '159680.m4a', '421387.m4a', '584800.m4a', '618224.m4a', '577176.m4a', '609265.m4a', '169009.m4a', '10010.m4a', '101031.m4a', '618254.m4a', '589809.m4a', '59841.m4a', '647936.m4a', '182182.m4a', '379433.m4a', '326588.m4a', '590506.m4a', '589246.m4a', '135588.m4a', '589956.m4a', '384143.m4a', '92043.m4a', '43639.m4a', '105869.m4a', '590411.m4a', '590488.m4a', '535650.m4a', '629390.m4a', '25676.m4a', '133433.m4a', '375841.m4a', '621925.m4a', '43637.m4a', '375858.m4a', '615386.m4a', '388634.m4a', '436655.m4a', '89649.m4a', '629419.m4a', '105894.m4a', '339107.m4a', '589967.m4a', '625054.m4a', '509610.m4a', '97720.m4a', '629395.m4a', '548527.m4a', '10978.m4a', '164633.m4a', '621990.m4a', '127410.m4a', '618230.m4a', '629380.m4a', '469340.m4a', '623251.m4a', '621944.m4a', '623642.m4a', '266048.m4a', '394189.m4a', '447274.m4a', '116973.m4a', '90811.m4a', '335811.m4a', '99734.m4a', '501475.m4a', '576353.m4a', '621941.m4a', '158926.m4a', '107282.m4a', '621917.m4a', '169006.m4a', '186927.m4a', '635275.m4a', '589560.m4a', '233636.m4a', '609258.m4a', '429629.m4a', '10153.m4a', '508950.m4a', '582806.m4a', '386640.m4a', '409360.m4a', '87178.m4a', '589063.m4a', '489936.m4a', '10279.m4a', '446708.m4a', '626683.m4a', '13094.m4a', '105918.m4a', '450056.m4a', '576368.m4a', '542357.m4a', '260519.m4a', '627952.m4a', '577145.m4a', '590380.m4a', '260365.m4a', '10282.m4a', '470856.m4a', '589546.m4a', '399329.m4a', '623506.m4a', '505139.m4a', '246457.m4a', '509889.m4a', '375880.m4a', '589577.m4a', '375878.m4a', '548388.m4a', '584773.m4a', '629415.m4a', '577213.m4a', '512568.m4a', '345440.m4a', '388427.m4a', '372960.m4a', '203615.m4a', '13120.m4a', '388669.m4a', '406070.m4a', '190563.m4a', '243248.m4a', '446578.m4a', '459503.m4a', '618231.m4a', '511383.m4a', '623208.m4a', '422967.m4a', '618226.m4a', '623537.m4a', '46698.m4a', '30755.m4a', '375435.m4a', '10098.m4a', '542352.m4a', '609563.m4a', '470818.m4a', '261624.m4a', '105830.m4a', '10117.m4a', '617962.m4a', '589244.m4a', '505136.m4a', '379691.m4a', '577143.m4a', '329355.m4a', '160841.m4a', '589946.m4a', '27470.m4a', '609981.m4a', '547146.m4a', '10030.m4a', '276300.m4a', '11052.m4a', '133624.m4a', '563469.m4a', '127408.m4a', '375694.m4a', '267787.m4a', '101099.m4a', '647926.m4a', '384151.m4a', '418652.m4a', '625790.m4a', '53331.m4a', '252153.m4a', '589799.m4a', '127761.m4a', '589949.m4a', '375859.m4a', '379368.m4a', '120842.m4a', '105929.m4a', '501011.m4a', '629381.m4a', '105866.m4a', '276384.m4a', '220170.m4a', '548551.m4a', '621713.m4a', '318735.m4a', '615382.m4a', '551335.m4a', '627264.m4a',  ...
# 3287
# {'modularsamples': 19887, 'soniktec': 116, 't0x1c-1': 5, 'tinga': 18, 'mooseranger': 6, 'darcyadam': 39, 'deleted-user-2104797': 431, 'uauaua': 88, 'kievinay': 4, 'minigunfiend': 16, 'craigsmith': 705, 'jalastram': 69, 'frederic-font': 90, 'kyles': 1383, 'strangehorizon': 1382, 'alexbuk': 76, 'deleted-user-2195044': 1077, 'crispydinner': 262, 'johnlavine333': 109, 'suddendice': 397, 'logicmoon': 12, 'batchku': 555, 'tripjazz': 310, 'blaukreuz': 10, 'samulis': 1658, 'shintaboy': 44, 'tehteho': 5, '16hpanskaresatko-matej': 4, 'lartti': 83, 'badoink': 728, 'joao-janz': 125, 'camilo-vargas13': 30, 'potentjello': 90, 'mrfossy': 805, 'tim-verberne': 44, 'zzztefanos': 168, 'hz37': 90, 'newagesoup': 170, 'ipaghost': 77, 'brasswork': 59, 'sgak': 90, 'fabianacarmonas': 67, 'duisterwho': 587, 'iykqic0': 32, 'ikaros350': 53, 'klerrp': 37, 'paisagemsonoraunila': 27, 'samuelburt': 90, 'necrosensual': 16, 'mattlohkamp': 19, 'giomilko': 90, 'spankmyfilth': 664, 'pepingrillin': 90, 'totalaj': 6, 'bananplyte': 19, 'gcguest1': 209, 'surrey-film': 5, 'pausenraum': 24, 'sergeyionov': 21, 'sturmankin': 359, 'miguelab1998': 43, 'jannevse': 2, 'bpt10zbu': 90, 'nicolas4677': 50, 'buddhafish': 7, 'qubodup': 166, 'danarobinsondesignsgmailcom': 79, 'charliecrash': 73, 'univ-lyon3': 336, 'dj-somar': 183, 'stomachache': 71, 'soneproject': 367, 'deleted-user-4397472': 87, 'o-ciz': 72, 'fabiopapa': 16, 'djmastah': 184, 'cabled-mess': 383, 'proyectosonidosias': 60, 'suicidity': 427, 'jokallset': 27, 'exechamp': 46, 'nicotep': 78, 'visual': 154, 'pjcohen': 90, 'sheyvan': 191, 'cormi': 13, 'galeku': 47, 'ironcross32': 90, 'akusmatech': 97, 'santiago27': 62, 'maciaac': 138, 'thecityrings': 236, 'frenkfurth': 29, 'hludowig': 90, '15gpanskahladikova-danuse': 7, 'thehorsevalse': 143, 'ntnvsl': 32, 'acollier123': 16, 'ryding': 32, 'bevibeldesign': 46, 'glitchedtones': 200, 'doug914': 12, 'dayvonjersen': 38, 'felix-blume': 422, 'jessariah': 35, 'blakengouda': 17, 'amberdemeillon': 9, 'lcscrts': 194, 'matias-reccius': 81, 'fonografico': 31, 'lollosound': 32, 'martinimeniscus': 90, 'buzzatsea': 42, 'nicjonesaudio': 1, 'nicholasdaryl': 29, 'puerta118m': 44, 'itinerantmonk108': 143, 'gherat': 102, 'nicolas-escobar-espinosa': 66, 'stamperadam': 44, 'artesmediales': 76, 'hisoul': 11, 'nome-diva': 90, 'nachtmahrtv': 5, 'mwsfx': 89, 'bruno-auzet': 4, 'cookies-policy': 13, 'guitarmaster': 15, 'jnvrbs': 14, 'profispiesser': 25, 'gameaudio': 41, 'tarane468': 24, 'linus-sebastian': 90, 'kmixsound': 13, 'deadrobotmusic': 448, 'erbsland-music': 30, 'the-runner-01': 90, 'kathakaku': 458, 'ishmaelberg': 41, 'hello-flowers': 134, 'tvfs': 55, 'yuval': 58, 'giocosound': 11, 'matze73': 90, 'eldiariosonoro': 111, 'unfa': 269, 'hypernovajm': 25, 'ipaddeh': 58, 'spartalien': 90, 'danielausme': 41, 'jaimage': 78, 'sieuamthanh': 473, 'miles-thompson': 62, 'alexiscanarvizuete92': 9, 'adcbicycle': 268, 'loudernoises': 12, 'nomiqbomi': 117, 'totalcult': 90, 'kedr-sfx': 14, 'veiler': 99, 'storyofthelie': 168, 'soloan': 17, 'vanyamba': 68, 'realdavidfloat': 124, 'owlstorm': 60, 'cms4f': 64, 'domingus': 4, 'vumseplutten1709': 81, 'gamba-studio': 57, 'magnuswaker': 34, 'austeritygirlone': 16, 'metrostock99': 38, 'iut-paris8': 300, 'rippleys-circus': 23, 'kingsrow': 33, 'byronbyron': 23, 'ldk1609': 156, 'rj13': 28, 'mielitietty': 124, 'basedmedia': 85, 'nickgoa': 61, 'mickyman5000': 180, 'bertsz': 6, 's-cheremisinov': 48, 'apinasaundi': 17, 'rebeat': 15, 'jamesabels': 21, 'zgump': 10, 'akustika': 167, 'fons': 21, 'saintsamael': 141, 'roses1401': 95, 'soundx360': 62, 'isaacmedina': 18, 'adh-dreaming': 45, 'anthousai': 165, 'milton': 23, 'sethlind': 32, 'frankum': 4, 'madamvicious': 69, 'karch': 46, 'javonninathanotero': 77, 'kreutzkamp': 12, 'danielovalle': 33, 'cbeeching': 114, 'rutgermuller': 195, 'masterjake2000': 44, 'graphite412': 13, 'lostchocolatelab': 25, 'irontec': 90, 'pjkasinski3': 15, 'kaiserd88': 82, 'urlande': 22, 'fynixx': 18, 'pbimal': 52, 'funwithsound': 192, 'stwime': 43, 'beskhu':  ...

# %%
def create_or_read_file(filename, command):
    if os.path.exists(filename):
        f = open(filename, "r")
        out = ''.join(f.readlines())
        f.close()
        return out
    else:
        try:
            out = str(subprocess.check_output(command).decode(encoding="utf-8")).strip().replace('\\n', '').replace("'", "")

            with open(filename, 'w') as file:
                file.write(out)

            return out
        except Exception as e:
            return

# %%
df = pd.DataFrame()
out_distances = {}
full_distances = []

for leftfilename in filenames:
    leftid = leftfilename.split('.')[0]
    rightfilenames = filenames
    rightfilenames = sorted(rightfilenames, key=lambda x: random())
    
    for righti, rightfilename in enumerate(rightfilenames):
        if (len(full_distances) % 100) == 0 and righti == 0:
            print(str(len(full_distances)) + " / " + str(len(filenames) * MAX_SAMPLE_COMPARISON_COUNT))
            
        if righti >= MAX_SAMPLE_COMPARISON_COUNT:
            continue
        
        if leftfilename == rightfilename:
            continue
            
        rightid = rightfilename.split('.')[0]
            
        try:
            correlation = correlate(wavpath, leftid, rightid, 'wav', dtwpath)
            
            if math.isinf(float(correlation)):
                continue
                
            if math.isnan(float(correlation)):
                continue
            
            df.loc[leftid, rightid] = correlation
            df.loc[rightid, leftid] = correlation

            if leftid not in out_distances:
                out_distances[leftid] = []
            
            sample_duration = sample_durations[leftid]
            out_distances[leftid].append([correlation, sample_duration, int(rightid)])
            full_distances.append([correlation, leftid, rightid])

        except Exception as e:
            pass

for filename in out_distances:
    out_distances[filename] = sorted(out_distances[filename])
    
full_distances = sorted(full_distances)
print(len(full_distances))
# Out:
# 0 / 82175
# 0 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# 1500 / 82175
# 1500 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# 1700 / 82175
# 1700 / 82175
# 1700 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# 10200 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# 12000 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# 13600 / 82175
# 13600 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:69: RuntimeWarning: invalid value encountered in double_scalars
#   c = a[0] - b[0]
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   d = a[i] - b[j]
# 14600 / 82175
# 14800 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: invalid value encountered in true_divide
#   normalized_samples = samples / max(samples)
# 15400 / 82175
# 15400 / 82175
# 15800 / 82175
# 15800 / 82175
# 15800 / 82175
# /Users/andrusasumets/projects/experiments/pacemaker/dtw.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   normalized_samples = samples / max(samples)
# 16300 / 82175
# 16600 / 82175
# 16600 / 82175
# 17500 / 82175
# 20200 / 82175
# 21500 / 82175
# 21500 / 82175
# 21500 / 82175
# 22300 / 82175
# 22900 / 82175
# 22900 / 82175
# 23500 / 82175
# 23500 / 82175
# 24000 / 82175
# 25300 / 82175
# 25300 / 82175
# 25700 / 82175
# 25700 / 82175
# 25700 / 82175
# 25700 / 82175
# 25700 / 82175
# 26900 / 82175
# 26900 / 82175
# 28500 / 82175
# 31300 / 82175
# 31300 / 82175
# 31300 / 82175
# 34416

# %%
delimiter = '|'
samples = {}
filtered_filenames = [f for f in os.listdir(dtwpath) if f.endswith('.dtw')]

for filename in filtered_filenames:
    filename = filename.split('.dtw')[0]
    left, right = filename.split(delimiter)
    
    if left not in samples:
        samples[left] = []
        
    if right not in samples:
        samples[right] = []
        
    samples[left].append(right)
    samples[right].append(left)

# %%
saved = []

for distance in full_distances:
    leftid = distance[1]
    
    if leftid in saved:
        continue
        
    saved.append(leftid)
    source = audiopath + leftid + '.' + audiofileformat
    target = extensionsamplepath + leftid + '.' + audiofileformat
    command = ['cp', source, target]
    process(command)

print(len(saved))

with open(extensionpath + 'distances.json', 'w') as fp:
    json.dump(out_distances, fp)
# Out:
# 2126

# %%
plot = sns.heatmap(df, xticklabels=False, yticklabels=False)
handles, labels = plot.get_legend_handles_labels()
plot.legend(reversed(handles), reversed(labels), title='', loc="lower right")
fig = plot.get_figure()
fig.tight_layout()
fig.savefig(extensionpath + "heatmap.png", dpi=1000, facecolor="white")

# %%
def show_audio(comparison):
    distance, leftid, rightid = comparison
    print(distance)

    data, rate = librosa.core.load(audiopath + leftid + '.' + audiofileformat)
    ipd.display(ipd.Audio(data, rate=rate))

    data, rate = librosa.core.load(audiopath + rightid + '.' + audiofileformat)
    ipd.display(ipd.Audio(data, rate=rate))

display_count = 10
for i in range(display_count):
    if (i % 2) == 0:
        show_audio(full_distances[i])
        
for i in range(display_count):
    if (i % 2) == 0:
        show_audio(full_distances[i - display_count])
# Out:
# 0.014973542934386188
# /usr/local/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /usr/local/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0.03156106684793457
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0.05108648581201099
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0.09814090211249418
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0.11488309164757199
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 11202209.579881657
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 11202316.120126072
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 11202811.981458003
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 11203580.75
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 11223723.17288539
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
